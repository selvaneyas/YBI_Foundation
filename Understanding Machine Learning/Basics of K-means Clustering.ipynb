# %% [markdown]
# # 📊 Basics of K-means Clustering
#
# Welcome to this interactive guide on K-means Clustering! Let's explore the theory, implementation, and applications of this popular clustering algorithm. 🚀

# %% [markdown]
# ## 1. Basics of K-means Clustering
#
# K-means is an unsupervised learning algorithm used to partition data into k distinct clusters based on feature similarity. 🧩

# %% [markdown]
# ## 2. Theory Behind K-means Clustering
#
# ### 2.1 Initialization
# - Choose k initial centroids randomly. 🎯
#
# ### 2.2 Assignment
# - Assign each data point to the nearest centroid. 📍
#
# ### 2.3 Update
# - Recalculate centroids as the mean of assigned points. 🔄
#
# ### 2.4 Report
# - Repeat assignment and update steps until convergence. 📈

# %% [markdown]
# ## 3. Example Scenario
#
# Imagine grouping customers based on purchasing behavior to target marketing campaigns effectively. 🎯

# %% [markdown]
# ## 4. Implementation Example
# ```python
# from sklearn.datasets import make_blobs
# from sklearn.cluster import KMeans
# import matplotlib.pyplot as plt
#
# # Generate sample data
# X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
#
# # Create KMeans instance
# kmeans = KMeans(n_clusters=4)
# kmeans.fit(X)
#
# # Plot clusters
# plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis')
# plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red')
# plt.title('K-means Clustering')
# plt.show()
# ```

# %% [markdown]
# ## 5. Explanation of the Code
#
# 1. **Data Preparation**: Generate synthetic data with `make_blobs`. 📊
# 2. **Feature Selection**: Use all features for clustering. 🧩
# 3. **K-means Clustering**: Fit the model to data. 🏋️‍♂️
# 4. **Cluster Assignment**: Assign points to clusters. 📍
# 5. **Visualization**: Plot clusters and centroids. 📈

# %% [markdown]
# ### Example Code

# %%
# !pip install --force-reinstall --upgrade matplotlib --user
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...

# %%
# !pip install --force-reinstall matplotlib --user
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.4-cp310-cp310-win_amd64.whl.metadata (108 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached matplotlib-3.10.3-cp310-cp310-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# Sample data : Annual spending on different categories(in thousamds)
data = {
    'Customer':['Aarav','Ishita','Rohan','Sneha','Neha','Vikram','Ananya','Arjun'],
    'Spending_on_Electronics':[15,20,14,25,30,18,22,24],
    'Spending_on_Clothing':[35,40,30,45,50,38,42,44]
}
df = pd.DataFrame(data)
df
# Out:
#   Customer  Spending_on_Electronics  Spending_on_Clothing
# 0    Aarav                       15                    35
# 1   Ishita                       20                    40
# 2    Rohan                       14                    30
# 3    Sneha                       25                    45
# 4     Neha                       30                    50
# 5   Vikram                       18                    38
# 6   Ananya                       22                    42
# 7    Arjun                       24                    44

# %%
# Extracting features for clustering
X = df[['Spending_on_Electronics','Spending_on_Clothing']]
X
# Out:
#    Spending_on_Electronics  Spending_on_Clothing
# 0                       15                    35
# 1                       20                    40
# 2                       14                    30
# 3                       25                    45
# 4                       30                    50
# 5                       18                    38
# 6                       22                    42
# 7                       24                    44

# %%
# Applying K-means clustering
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
# Adding cluster labels to the dataframe
df['Cluster'] = kmeans.labels_

print(df)
# Out:
#   Customer  Spending_on_Electronics  Spending_on_Clothing  Cluster
# 0    Aarav                       15                    35        1
# 1   Ishita                       20                    40        2
# 2    Rohan                       14                    30        1
# 3    Sneha                       25                    45        2
# 4     Neha                       30                    50        0
# 5   Vikram                       18                    38        2
# 6   Ananya                       22                    42        2
# 7    Arjun                       24                    44        2

# %%
# Visualizing the clusters
plt.scatter(df['Spending_on_Electronics'], df['Spending_on_Clothing'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Spending on Electronics (in thousands)')
plt.ylabel('Spending on Clothing (in thousands)')
plt.title('Customer Segmentation using K-means Clustering')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ## 6. Applications of K-means Clustering
#
# - Customer segmentation 👥
# - Image compression 🖼️
# - Document clustering 📄
# - Anomaly detection 🚨

# %% [markdown]
# ## 7. Further Reading
#
# - Choosing the right number of clusters (Elbow method, Silhouette score) 🎯
# - Handling large datasets with mini-batch K-means 🐢
# - Advanced clustering techniques (DBSCAN, Hierarchical clustering) 🌲
